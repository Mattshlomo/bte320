# %% [markdown]
# <a href="https://colab.research.google.com/github/Mattshlomo/bte320/blob/main/In_Class_Assignments.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
sales = float(input("Enter sales ($): "))
cogs = sales * 0.40
gross_profit = sales - cogs
tax_rate_percent = float(input("Enter tax rate (%): "))
tax_rate = tax_rate_percent / 100
taxes = gross_profit * tax_rate
net_income = gross_profit - taxes
print(f"Sales:{sales}$")
print(f"Cost of Goods Sold:{cogs}$")
print(f"Gross Profit:{gross_profit}$")
print(f"Taxes:{taxes}$")
print(f"Net Income:{net_income}$")
# Out:
# Enter sales ($): 12000
# Enter tax rate (%): 30
# Sales:12000.0$
# Cost of Goods Sold:4800.0$
# Gross Profit:7200.0$
# Taxes:2160.0$
# Net Income:5040.0$

# %% [markdown]
# Week 3

# %%
if condition:
  exprs
elif another_condition:
  exprs
else:
  exprs

# %%
email = "URGENT!! Login to www.phis.org immediately otherwise your account will be suspended"
has_urgent = "URGENT"
has_www = "www."

if has_urgent in email:
  print("Phishing!")
elif has_www in email:
  print("Spam!")
else:
    print('Legit!')
# Out:
# Phishing!

# %%
grade = float(input("Enter numerical grade (1-100):"))

if grade >= 97:
  print("A+")
elif grade >= 93:
  print("A")
elif grade >= 90:
  print("A-")
# Out:
# Enter numerical grade (1-100):99
# A+
